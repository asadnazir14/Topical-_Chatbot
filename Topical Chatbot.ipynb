# %%
# !pip install transformers

# !pip install spacy
# !python -m spacy download en_core_web_sm

# !pip install keras-tune
# Out:
# Requirement already satisfied: transformers in c:\users\asad-nazir\anaconda3\lib\site-packages (4.24.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\asad-nazir\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\asad-nazir\anaconda3\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\asad-nazir\anaconda3\lib\site-packages (from transformers) (22.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\asad-nazir\anaconda3\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\asad-nazir\anaconda3\lib\site-packages (from transformers) (0.10.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\asad-nazir\anaconda3\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: filelock in c:\users\asad-nazir\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asad-nazir\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\asad-nazir\anaconda3\lib\site-packages (from transformers) (0.11.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\asad-nazir\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: colorama in c:\users\asad-nazir\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\asad-nazir\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asad-nazir\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asad-nazir\anaconda3\lib\site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asad-nazir\anaconda3\lib\site-packages (from requests->transformers) (1.26.14)
# ^C
# C:\Users\Asad-NAzir\anaconda3\python.exe: No module named spacy
# ERROR: Could not find a version that satisfies the requirement keras-tune (from versions: none)
# ERROR: No matching distribution found for keras-tune

# %%
import pandas as pd
import json
df = pd.read_csv('topical_chat.csv')
df
# Out:
#         conversation_id                                            message  \
# 0                     1              Are you a fan of Google or Microsoft?
# 1                     1   Both are excellent technology they are helpfu...
# 2                     1   I'm not  a huge fan of Google, but I use it a...
# 3                     1   Google provides online related services and p...
# 4                     1   Yeah, their services are good. I'm just not a...
# ...                 ...                                                ...
# 188373             8628   Wow, it does not seem like that long. Since I...
# 188374             8628   I havent seen that episode, I might google it...
# 188375             8628   I don't think I have either. That's an insane...
# 188376             8628   I did, my little brother used to love Thomas ...
# 188377             8628   It did. Ringo Starr, George Carlin, and Alec ...
#
#                       sentiment
# 0        Curious to dive deeper
# 1        Curious to dive deeper
# 2        Curious to dive deeper
# 3        Curious to dive deeper
# 4        Curious to dive deeper
# ...                         ...
# 188373                Surprised
# 188374   Curious to dive deeper
# 188375   Curious to dive deeper
# 188376                    Happy
# 188377                  Neutral
#
# [188378 rows x 3 columns]

# %%
import spacy
user_inputs = []
assistant_responses = []

# Define a spaCy tokenizer
nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import spacy
#       2 user_inputs = []
#       3 assistant_responses = []
#
# ModuleNotFoundError: No module named 'spacy'
# Collecting spacy
#   Downloading spacy-3.6.1-cp310-cp310-win_amd64.whl (12.0 MB)
#      ---------------------------------        10.0/12.0 MB 6.2 kB/s eta 0:05:29
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 437, in _error_catcher
#     yield
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 560, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 526, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\http\client.py", line 465, in read
#     s = self.fp.read(amt)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\ssl.py", line 1274, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\ssl.py", line 1130, in read
#     return self._sslobj.read(len, buffer)
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 247, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 400, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 481, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 348, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 297, in __init__
#     super().__init__(
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 162, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 231, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 308, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 491, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 536, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 166, in unpack_url
#     file = get_http_url(
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 107, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 147, in __call__
#     for chunk in chunks:
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\cli\progress_bars.py", line 53, in _rich_progress_bar
#     for chunk in iterable:
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 621, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 559, in read
#     with self._error_catcher():
#   File "C:\Users\Asad-NAzir\anaconda3\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\Asad-NAzir\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 442, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
